# %% [markdown]
# # Intro - Mass Mobilization Data

# %% [markdown]
# ### Data covers the protests demands and the governement's response across 162 countries worldwide. The aim of our project is to predict the likely hood of a protest's demand being accomodated by local governments vs. being ignored, or unresolved.
# ### Data contains key variables such as country, dates, demands, responses among others, that will be considered in building a binary classification model to predict an outcome of Accomodation (1) or No Accomodation (0)

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import datetime

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures, StandardScaler

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('./data/mmALL_073119_csv.csv')

# %%
df.shape
# Out:
# (16363, 31)

# %% [markdown]
# ### Data Info and Type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16363 entries, 0 to 16362
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     16363 non-null  int64
#  1   country                16363 non-null  object
#  2   ccode                  16363 non-null  int64
#  3   year                   16363 non-null  int64
#  4   region                 16363 non-null  object
#  5   protest                16363 non-null  int64
#  6   protestnumber          16363 non-null  int64
#  7   startday               14514 non-null  float64
#  8   startmonth             14514 non-null  float64
#  9   startyear              14514 non-null  float64
#  10  endday                 14514 non-null  float64
#  11  endmonth               14514 non-null  float64
#  12  endyear                14514 non-null  float64
#  13  protesterviolence      15033 non-null  float64
#  14  location               14493 non-null  object
#  15  participants_category  9160 non-null   object
#  16  participants           15021 non-null  object
#  17  protesteridentity      13959 non-null  object
#  18  protesterdemand1       14503 non-null  object
#  19  protesterdemand2       2676 non-null   object
#  20  protesterdemand3       316 non-null    object
#  21  protesterdemand4       896 non-null    object
#  22  stateresponse1         14483 non-null  object
#  23  stateresponse2         2716 non-null   object
#  24  stateresponse3         850 non-null    object
#  25  stateresponse4         230 non-null    object
#  26  stateresponse5         926 non-null    object
#  27  stateresponse6         16 non-null     object
#  28  stateresponse7         920 non-null    object
#  29  sources                14510 non-null  object
#  30  notes                  14468 non-null  object
# dtypes: float64(7), int64(5), object(19)
# memory usage: 3.9+ MB

# %% [markdown]
# ### Protest count by region and country

# %%
df.groupby(['region', 'country'])['id'].count().sort_index()
# Out:
# region           country
# Africa           Angola                       37
#                  Benin                        44
#                  Botswana                     50
#                  Burkina Faso                 78
#                  Burundi                     109
#                  Cameroon                     67
#                  Cape Verde                   31
#                  Central African Republic     68
#                  Chad                         38
#                  Comoros                      91
#                  Congo Brazzaville            51
#                  Congo Kinshasa               78
#                  Djibouti                     31
#                  Equatorial Guinea            30
#                  Eritrea                      30
#                  Ethiopia                     49
#                  Gabon                        47
#                  Gambia                       39
#                  Ghana                        76
#                  Guinea                      101
#                  Guinea-Bissau                45
#                  Ivory Coast                 119
#                  Kenya                       350
#                  Lesotho                      49
#                  Liberia                      73
#                  Madagascar                  120
#                  Malawi                       59
#                  Mali                         57
#                  Mauritania                   90
#                  Mauritius                    34
#                  Mozambique                   81
#                  Namibia                     233
#                  Niger                       113
#                  Nigeria                     159
#                  Rwanda                       35
#                  Senegal                      58
#                  Sierra Leone                 50
#                  Somalia                      41
#                  South Africa                173
#                  South Sudan                   9
#                  Swaziland                   104
#                  Tanzania                     53
#                  Togo                        101
#                  Uganda                       69
#                  Zambia                       98
#                  Zimbabwe                    112
# Asia             Afghanistan                  55
#                  Bangladesh                  339
#                  Bhutan                       30
#                  Cambodia                     66
#                  China                       265
#                  India                       204
#                  Indonesia                   147
#                  Japan                        70
#                  Kazakhstan                   86
#                  Kyrgyzstan                  169
#                  Laos                         30
#                  Malaysia                    151
#                  Mongolia                     61
#                  Myanmar                      89
#                  Nepal                       211
#                  North Korea                  31
#                  Pakistan                    174
#                  Philippines                  70
#                  Singapore                    38
#                  South Korea                 346
#                  Sri Lanka                    80
#                  Taiwan                      149
#                  Tajikistan                   50
#                  Thailand                    249
#                  Timor Leste                  21
#                  Turkmenistan                 30
#                  Uzbekistan                   54
#                  Vietnam                      35
# Central America  Costa Rica                   52
#                  El Salvador                  65
#                  Guatemala                   113
#                  Honduras                    108
#                  Nicaragua                    89
#                  Panama                       57
# Europe           Albania                      82
#                  Armenia                     106
#                  Austria                      31
#                  Azerbaijan                  131
#                  Belarus                      77
#                  Belgium                      55
#                  Bosnia                       48
#                  Bulgaria                    130
#                  Croatia                      39
#                  Cyprus                      138
#                  Czech Republic               39
#                  Czechoslovakia                6
#                  Denmark                      33
#                  Estonia                      63
#                  Finland                      35
#                  France                      527
#                  Georgia                      65
#                  Germany                     360
#                  Germany East                 11
#                  Germany West                  2
#                  Greece                      309
#                  Hungary                      74
#                  Ireland                     434
#                  Italy                       164
#                  Kosovo                       22
#                  Latvia                       97
#                  Lithuania                    52
#                  Luxembourg                   31
#                  Macedonia                    85
#                  Moldova                     113
#                  Montenegro                   17
#                  Netherlands                  34
#                  Norway                       31
#                  Poland                      122
#                  Portugal                     46
#                  Romania                     222
#                  Russia                      192
#                  Serbia                       31
#                  Serbia and Montenegro         5
#                  Slovak Republic              54
#                  Slovenia                     39
#                  Spain                       157
#                  Sweden                       36
#                  Switzerland                  30
#                  USSR                         60
#                  Ukraine                     157
#                  United Kingdom              547
#                  Yugoslavia                  138
# MENA             Algeria                      74
#                  Bahrain                      63
#                  Egypt                       133
#                  Iran                        121
#                  Iraq                        113
#                  Jordan                       63
#                  Kuwait                       56
#                  Lebanon                      69
#                  Libya                        45
#                  Morocco                      51
#                  Oman                         52
#                  Qatar                        30
#                  Saudi Arabia                 42
#                  Sudan                        71
#                  Syria                        38
#                  Tunisia                      61
#                  Turkey                      133
#                  United Arab Emirate          30
#                  Yemen                       165
# North America    Canada                       57
#                  Cuba                        120
#                  Dominican Republic           81
#                  Haiti                       112
#                  Jamaica                      44
#                  Mexico                      146
# Oceania          Papua New Guinea             49
# South America    Argentina                   116
#                  Bolivia                     131
#                  Brazil                      221
#                  Chile                       157
#                  Colombia                    136
#                  Ecuador                     153
#                  Guyana                       48
#                  Paraguay                     71
#                  Peru                        165
#                  Suriname                     64
#                  Uruguay                      76
#                  Venezuela                   315
# Name: id, dtype: int64

# %% [markdown]
# ### Protest total count by region
#
# * Europe leads all other regions worldwide with the most amount of protests

# %%
df.groupby(['region'])['id'].count().sort_values(ascending = False)
# Out:
# region
# Europe             5277
# Africa             3630
# Asia               3300
# South America      1653
# MENA               1410
# North America       560
# Central America     484
# Oceania              49
# Name: id, dtype: int64

# %% [markdown]
# ### Protest count by country
#
# * UK, France, Ireland, and Germany are the top 4 countries with the most amount of protests

# %%
df.groupby(['country'])['id'].count().sort_values(ascending = False)
# Out:
# country
# United Kingdom              547
# France                      527
# Ireland                     434
# Germany                     360
# Kenya                       350
# South Korea                 346
# Bangladesh                  339
# Venezuela                   315
# Greece                      309
# China                       265
# Thailand                    249
# Namibia                     233
# Romania                     222
# Brazil                      221
# Nepal                       211
# India                       204
# Russia                      192
# Pakistan                    174
# South Africa                173
# Kyrgyzstan                  169
# Yemen                       165
# Peru                        165
# Italy                       164
# Nigeria                     159
# Spain                       157
# Ukraine                     157
# Chile                       157
# Ecuador                     153
# Malaysia                    151
# Taiwan                      149
# Indonesia                   147
# Mexico                      146
# Yugoslavia                  138
# Cyprus                      138
# Colombia                    136
# Egypt                       133
# Turkey                      133
# Bolivia                     131
# Azerbaijan                  131
# Bulgaria                    130
# Poland                      122
# Iran                        121
# Madagascar                  120
# Cuba                        120
# Ivory Coast                 119
# Argentina                   116
# Moldova                     113
# Niger                       113
# Iraq                        113
# Guatemala                   113
# Haiti                       112
# Zimbabwe                    112
# Burundi                     109
# Honduras                    108
# Armenia                     106
# Swaziland                   104
# Guinea                      101
# Togo                        101
# Zambia                       98
# Latvia                       97
# Comoros                      91
# Mauritania                   90
# Nicaragua                    89
# Myanmar                      89
# Kazakhstan                   86
# Macedonia                    85
# Albania                      82
# Mozambique                   81
# Dominican Republic           81
# Sri Lanka                    80
# Congo Kinshasa               78
# Burkina Faso                 78
# Belarus                      77
# Ghana                        76
# Uruguay                      76
# Algeria                      74
# Hungary                      74
# Liberia                      73
# Paraguay                     71
# Sudan                        71
# Japan                        70
# Philippines                  70
# Uganda                       69
# Lebanon                      69
# Central African Republic     68
# Cameroon                     67
# Cambodia                     66
# El Salvador                  65
# Georgia                      65
# Suriname                     64
# Estonia                      63
# Jordan                       63
# Bahrain                      63
# Tunisia                      61
# Mongolia                     61
# USSR                         60
# Malawi                       59
# Senegal                      58
# Canada                       57
# Panama                       57
# Mali                         57
# Kuwait                       56
# Afghanistan                  55
# Belgium                      55
# Slovak Republic              54
# Uzbekistan                   54
# Tanzania                     53
# Oman                         52
# Lithuania                    52
# Costa Rica                   52
# Morocco                      51
# Congo Brazzaville            51
# Sierra Leone                 50
# Tajikistan                   50
# Botswana                     50
# Papua New Guinea             49
# Ethiopia                     49
# Lesotho                      49
# Guyana                       48
# Bosnia                       48
# Gabon                        47
# Portugal                     46
# Libya                        45
# Guinea-Bissau                45
# Jamaica                      44
# Benin                        44
# Saudi Arabia                 42
# Somalia                      41
# Croatia                      39
# Gambia                       39
# Czech Republic               39
# Slovenia                     39
# Syria                        38
# Chad                         38
# Singapore                    38
# Angola                       37
# Sweden                       36
# Vietnam                      35
# Finland                      35
# Rwanda                       35
# Netherlands                  34
# Mauritius                    34
# Denmark                      33
# North Korea                  31
# Norway                       31
# Austria                      31
# Luxembourg                   31
# Djibouti                     31
# Serbia                       31
# Cape Verde                   31
# Laos                         30
# Equatorial Guinea            30
# Eritrea                      30
# United Arab Emirate          30
# Switzerland                  30
# Qatar                        30
# Bhutan                       30
# Turkmenistan                 30
# Kosovo                       22
# Timor Leste                  21
# Montenegro                   17
# Germany East                 11
# South Sudan                   9
# Czechoslovakia                6
# Serbia and Montenegro         5
# Germany West                  2
# Name: id, dtype: int64

# %% [markdown]
# ### Initial protest demand count worldwide
#
# * political behavior is the leading cause of protests globally

# %%
df['protesterdemand1'].value_counts()
# Out:
# political behavior, process    9181
# labor wage dispute             1667
# price increases, tax policy    1059
# removal of politician           950
# police brutality                785
# land farm issue                 448
# social restrictions             413
# Name: protesterdemand1, dtype: int64

# %% [markdown]
# ### Initial govt. response worldwide
#
# * Ignoring the issue is the leading response, followed by dispersing crowds

# %%
df['stateresponse1'].value_counts()
# Out:
# ignore             7934
# crowd dispersal    3612
# arrests            1049
# accomodation        937
# shootings           415
# beatings            300
# killings            236
# Name: stateresponse1, dtype: int64

# %% [markdown]
# ### Protest demands by country

# %%
pd.crosstab(df['region'], df['protesterdemand1'])
# Out:
# protesterdemand1  labor wage dispute  land farm issue  police brutality  \
# region
# Africa                           429              104               156
# Asia                             268              159               259
# Central America                   50               16                 7
# Europe                           591              127               155
# MENA                              58               13               112
# North America                     26               10                52
# Oceania                            4                1                 6
# South America                    241               18                38
#
# protesterdemand1  political behavior, process  price increases, tax policy  \
# region
# Africa                                   1868                          217
# Asia                                     1736                          177
# Central America                           262                           65
# Europe                                   3151                          380
# MENA                                      669                           76
# North America                             351                           37
# Oceania                                    21                            0
# South America                            1123                          107
#
# protesterdemand1  removal of politician  social restrictions
# region
# Africa                              215                   52
# Asia                                246                  139
# Central America                      33                    1
# Europe                              263                  144
# MENA                                110                   55
# North America                        20                    4
# Oceania                               6                    0
# South America                        57                   18

# %%
pd.crosstab(df['region'], df['stateresponse1'])
# Out:
# stateresponse1   accomodation  arrests  beatings  crowd dispersal  ignore  \
# region
# Africa                    248      217        62             1029    1253
# Asia                      213      279       132              681    1499
# Central America            19       14         2              128     259
# Europe                    234      255        50              997    3245
# MENA                       57       96        43              283     481
# North America              33       70         7               80     288
# Oceania                    10        0         0                9      17
# South America             123      118         4              405     892
#
# stateresponse1   killings  shootings
# region
# Africa                 63        164
# Asia                   86         89
# Central America         0         12
# Europe                  6         21
# MENA                   41         92
# North America           1         21
# Oceania                 0          2
# South America          39         14

# %%
df.groupby(['region'])['protesterdemand1'].value_counts(normalize = True)
# Out:
# region           protesterdemand1
# Africa           political behavior, process    0.614272
#                  labor wage dispute             0.141072
#                  price increases, tax policy    0.071358
#                  removal of politician          0.070700
#                  police brutality               0.051299
#                  land farm issue                0.034199
#                  social restrictions            0.017100
# Asia             political behavior, process    0.581769
#                  labor wage dispute             0.089812
#                  police brutality               0.086796
#                  removal of politician          0.082440
#                  price increases, tax policy    0.059316
#                  land farm issue                0.053284
#                  social restrictions            0.046582
# Central America  political behavior, process    0.603687
#                  price increases, tax policy    0.149770
#                  labor wage dispute             0.115207
#                  removal of politician          0.076037
#                  land farm issue                0.036866
#                  police brutality               0.016129
#                  social restrictions            0.002304
# Europe           political behavior, process    0.654957
#                  labor wage dispute             0.122843
#                  price increases, tax policy    0.078986
#                  removal of politician          0.054666
#                  police brutality               0.032218
#                  social restrictions            0.029931
#                  land farm issue                0.026398
# MENA             political behavior, process    0.612077
#                  police brutality               0.102470
#                  removal of politician          0.100640
#                  price increases, tax policy    0.069533
#                  labor wage dispute             0.053065
#                  social restrictions            0.050320
#                  land farm issue                0.011894
# North America    political behavior, process    0.702000
#                  police brutality               0.104000
#                  price increases, tax policy    0.074000
#                  labor wage dispute             0.052000
#                  removal of politician          0.040000
#                  land farm issue                0.020000
#                  social restrictions            0.008000
# Oceania          political behavior, process    0.552632
#                  police brutality               0.157895
#                  removal of politician          0.157895
#                  labor wage dispute             0.105263
#                  land farm issue                0.026316
# South America    political behavior, process    0.700999
#                  labor wage dispute             0.150437
#                  price increases, tax policy    0.066792
#                  removal of politician          0.035581
#                  police brutality               0.023720
#                  land farm issue                0.011236
#                  social restrictions            0.011236
# Name: protesterdemand1, dtype: float64

# %%
df.groupby(['region'])['stateresponse1'].value_counts(normalize = True)
# Out:
# region           stateresponse1
# Africa           ignore             0.412714
#                  crowd dispersal    0.338933
#                  accomodation       0.081686
#                  arrests            0.071476
#                  shootings          0.054018
#                  killings           0.020751
#                  beatings           0.020422
# Asia             ignore             0.503189
#                  crowd dispersal    0.228600
#                  arrests            0.093656
#                  accomodation       0.071501
#                  beatings           0.044310
#                  shootings          0.029876
#                  killings           0.028869
# Central America  ignore             0.596774
#                  crowd dispersal    0.294931
#                  accomodation       0.043779
#                  arrests            0.032258
#                  shootings          0.027650
#                  beatings           0.004608
# Europe           ignore             0.674917
#                  crowd dispersal    0.207363
#                  arrests            0.053037
#                  accomodation       0.048669
#                  beatings           0.010399
#                  shootings          0.004368
#                  killings           0.001248
# MENA             ignore             0.440073
#                  crowd dispersal    0.258920
#                  arrests            0.087832
#                  shootings          0.084172
#                  accomodation       0.052150
#                  beatings           0.039341
#                  killings           0.037511
# North America    ignore             0.576000
#                  crowd dispersal    0.160000
#                  arrests            0.140000
#                  accomodation       0.066000
#                  shootings          0.042000
#                  beatings           0.014000
#                  killings           0.002000
# Oceania          ignore             0.447368
#                  accomodation       0.263158
#                  crowd dispersal    0.236842
#                  shootings          0.052632
# South America    ignore             0.559248
#                  crowd dispersal    0.253918
#                  accomodation       0.077116
#                  arrests            0.073981
#                  killings           0.024451
#                  shootings          0.008777
#                  beatings           0.002508
# Name: stateresponse1, dtype: float64

# %% [markdown]
# ### in relation to the amount of protests per region, Middle Eastern North Africa has the most killings
#
# ### Europe, North America, and Oceania have the least

# %%
df.groupby(['protesterdemand1'])['region'].value_counts(normalize = True)
# Out:
# protesterdemand1             region
# labor wage dispute           Europe             0.354529
#                              Africa             0.257349
#                              Asia               0.160768
#                              South America      0.144571
#                              MENA               0.034793
#                              Central America    0.029994
#                              North America      0.015597
#                              Oceania            0.002400
# land farm issue              Asia               0.354911
#                              Europe             0.283482
#                              Africa             0.232143
#                              South America      0.040179
#                              Central America    0.035714
#                              MENA               0.029018
#                              North America      0.022321
#                              Oceania            0.002232
# police brutality             Asia               0.329936
#                              Africa             0.198726
#                              Europe             0.197452
#                              MENA               0.142675
#                              North America      0.066242
#                              South America      0.048408
#                              Central America    0.008917
#                              Oceania            0.007643
# political behavior, process  Europe             0.343209
#                              Africa             0.203464
#                              Asia               0.189086
#                              South America      0.122318
#                              MENA               0.072868
#                              North America      0.038231
#                              Central America    0.028537
#                              Oceania            0.002287
# price increases, tax policy  Europe             0.358829
#                              Africa             0.204910
#                              Asia               0.167139
#                              South America      0.101039
#                              MENA               0.071766
#                              Central America    0.061379
#                              North America      0.034939
# removal of politician        Europe             0.276842
#                              Asia               0.258947
#                              Africa             0.226316
#                              MENA               0.115789
#                              South America      0.060000
#                              Central America    0.034737
#                              North America      0.021053
#                              Oceania            0.006316
# social restrictions          Europe             0.348668
#                              Asia               0.336562
#                              MENA               0.133172
#                              Africa             0.125908
#                              South America      0.043584
#                              North America      0.009685
#                              Central America    0.002421
# Name: region, dtype: float64

# %%
df.groupby(['stateresponse1'])['region'].value_counts(normalize = True)
# Out:
# stateresponse1   region
# accomodation     Africa             0.264674
#                  Europe             0.249733
#                  Asia               0.227321
#                  South America      0.131270
#                  MENA               0.060832
#                  North America      0.035219
#                  Central America    0.020277
#                  Oceania            0.010672
# arrests          Asia               0.265968
#                  Europe             0.243089
#                  Africa             0.206864
#                  South America      0.112488
#                  MENA               0.091516
#                  North America      0.066730
#                  Central America    0.013346
# beatings         Asia               0.440000
#                  Africa             0.206667
#                  Europe             0.166667
#                  MENA               0.143333
#                  North America      0.023333
#                  South America      0.013333
#                  Central America    0.006667
# crowd dispersal  Africa             0.284884
#                  Europe             0.276024
#                  Asia               0.188538
#                  South America      0.112126
#                  MENA               0.078350
#                  Central America    0.035437
#                  North America      0.022148
#                  Oceania            0.002492
# ignore           Europe             0.408999
#                  Asia               0.188934
#                  Africa             0.157928
#                  South America      0.112428
#                  MENA               0.060625
#                  North America      0.036299
#                  Central America    0.032644
#                  Oceania            0.002143
# killings         Asia               0.364407
#                  Africa             0.266949
#                  MENA               0.173729
#                  South America      0.165254
#                  Europe             0.025424
#                  North America      0.004237
# shootings        Africa             0.395181
#                  MENA               0.221687
#                  Asia               0.214458
#                  Europe             0.050602
#                  North America      0.050602
#                  South America      0.033735
#                  Central America    0.028916
#                  Oceania            0.004819
# Name: region, dtype: float64

# %%
# changed 

df['outcome'] = df['stateresponse1'].apply(lambda x: 1 if x == 'accomodation' else int(0))

# %% [raw]
# ignore             7934
# crowd dispersal    3612
# arrests            1049
# accomodation        937
# shootings           415
# beatings            300
# killings            236

# %% [markdown]
# ### Total count worldwide of Accomodations (1) and No Accomodations (0)
# * Accomodations make up nearly 5% worldwide of outcomes

# %%
df['outcome'].value_counts()
# Out:
# 0    15426
# 1      937
# Name: outcome, dtype: int64

# %%
df['outcome'].value_counts( normalize = True)
# Out:
# 0    0.942737
# 1    0.057263
# Name: outcome, dtype: float64

# %%
### Grouping stateresponse based on violent and non violent protests

# %%
df.groupby(['protesterviolence'])['stateresponse1'].value_counts(normalize = True)
# Out:
# protesterviolence  stateresponse1
# 0.0                ignore             0.691335
#                    crowd dispersal    0.141827
#                    accomodation       0.076347
#                    arrests            0.058454
#                    shootings          0.015082
#                    beatings           0.010023
#                    killings           0.006932
# 1.0                crowd dispersal    0.550945
#                    ignore             0.145483
#                    arrests            0.111607
#                    shootings          0.066702
#                    beatings           0.050683
#                    killings           0.042542
#                    accomodation       0.032038
# Name: stateresponse1, dtype: float64

# %%
df.groupby(['protesterviolence','region'])['stateresponse1'].value_counts(normalize = True)
# Out:
# protesterviolence  region           stateresponse1
# 0.0                Africa           ignore             0.556549
#                                     crowd dispersal    0.225145
#                                     accomodation       0.110468
#                                     arrests            0.055234
#                                     shootings          0.029458
#                                     beatings           0.013677
#                                     killings           0.009469
#                    Asia             ignore             0.670471
#                                     crowd dispersal    0.129815
#                                     accomodation       0.085592
#                                     arrests            0.075131
#                                     beatings           0.014265
#                                     shootings          0.014265
#                                     killings           0.010461
#                    Central America  ignore             0.764310
#                                     crowd dispersal    0.144781
#                                     accomodation       0.063973
#                                     arrests            0.016835
#                                     shootings          0.006734
#                                     beatings           0.003367
#                    Europe           ignore             0.792525
#                                     crowd dispersal    0.102466
#                                     accomodation       0.054666
#                                     arrests            0.041953
#                                     beatings           0.005339
#                                     shootings          0.002797
#                                     killings           0.000254
#                    MENA             ignore             0.568900
#                                     crowd dispersal    0.189633
#                                     arrests            0.079646
#                                     shootings          0.061947
#                                     accomodation       0.060683
#                                     beatings           0.027813
#                                     killings           0.011378
#                    North America    ignore             0.699717
#                                     arrests            0.150142
#                                     accomodation       0.073654
#                                     crowd dispersal    0.048159
#                                     shootings          0.014164
#                                     beatings           0.011331
#                                     killings           0.002833
#                    Oceania          ignore             0.500000
#                                     accomodation       0.346154
#                                     crowd dispersal    0.153846
#                    South America    ignore             0.675059
#                                     crowd dispersal    0.154209
#                                     accomodation       0.084972
#                                     arrests            0.059009
#                                     killings           0.018096
#                                     shootings          0.006294
#                                     beatings           0.002360
# 1.0                Africa           crowd dispersal    0.529515
#                                     ignore             0.171806
#                                     arrests            0.098678
#                                     shootings          0.095154
#                                     killings           0.039648
#                                     accomodation       0.033480
#                                     beatings           0.031718
#                    Asia             crowd dispersal    0.465753
#                                     arrests            0.138128
#                                     beatings           0.116438
#                                     ignore             0.101598
#                                     killings           0.073059
#                                     shootings          0.067352
#                                     accomodation       0.037671
#                    Central America  crowd dispersal    0.620438
#                                     ignore             0.233577
#                                     shootings          0.072993
#                                     arrests            0.065693
#                                     beatings           0.007299
#                    Europe           crowd dispersal    0.678857
#                                     ignore             0.146286
#                                     arrests            0.102857
#                                     beatings           0.033143
#                                     accomodation       0.021714
#                                     shootings          0.011429
#                                     killings           0.005714
#                    MENA             crowd dispersal    0.440397
#                                     shootings          0.142384
#                                     arrests            0.109272
#                                     killings           0.105960
#                                     ignore             0.102649
#                                     beatings           0.069536
#                                     accomodation       0.029801
#                    North America    crowd dispersal    0.428571
#                                     ignore             0.278912
#                                     arrests            0.115646
#                                     shootings          0.108844
#                                     accomodation       0.047619
#                                     beatings           0.020408
#                    Oceania          crowd dispersal    0.416667
#                                     ignore             0.333333
#                                     shootings          0.166667
#                                     accomodation       0.083333
#                    South America    crowd dispersal    0.645062
#                                     arrests            0.132716
#                                     ignore             0.104938
#                                     killings           0.049383
#                                     accomodation       0.046296
#                                     shootings          0.018519
#                                     beatings           0.003086
# Name: stateresponse1, dtype: float64

# %% [markdown]
# ### Filtering data on rows with protests

# %%
# created a second data frame based on 1 or more protest 
# alternative to deleting NaN dates 

df2 = df[df['protestnumber']>0].copy()

# %% [markdown]
# ### Creating duration, start date, and end date of protests

# %%
df2['startyear'] = df2['startyear'].astype(int)
df2['startmonth'] = df2['startmonth'].astype(int)
df2['startday'] = df2['startday'].astype(int)
df2['endyear'] = df2['endyear'].astype(int)
df2['endmonth'] = df2['endmonth'].astype(int)
df2['endday'] = df2['endday'].astype(int)


df2['startdate'] = df2.apply(lambda x: datetime.date(x['startyear'], x['startmonth'], x['startday']), axis = 1)

df2['enddate'] = df2.apply(lambda x: datetime.date(x['endyear'], x['endmonth'], x['endday']), axis = 1)

df2['startdate'] = pd.to_datetime(df2['startdate'])
df2['enddate'] = pd.to_datetime(df2['enddate'])

df2['datedelta'] = df2['enddate'] - df2['startdate']
df2['datedelta'] = df2['datedelta'].dt.days.astype(int)

# %% [markdown]
# ### count of protest per year
# * Protests gradually increased in 2014 and 2015

# %%
df2.groupby(['year'])['id'].count().sort_index().plot.bar()

# %% [markdown]
# ### Protests counts per region

# %%
df2.groupby(['region'])['id'].count().sort_values(ascending = False).plot.bar()

# %% [markdown]
# ### Protests by year by region

# %%
pd.crosstab(df2['region'], df2['year']).style.background_gradient(cmap = 'coolwarm')
# Out:
# <style  type="text/css" >
#     #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row0_col0 {
#             background-color:  #97b8ff;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row0_col1 {
#             background-color:  #f59d7e;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row0_col2 {
#             background-color:  #e9d5cb;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row0_col3 {
#             background-color:  #f7b99e;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row0_col4 {
#             background-color:  #f7aa8c;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row0_col5 {
#             background-color:  #b6cefa;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row0_col6 {
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row0_col7 {
#             background-color:  #e1dad6;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row0_col8 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row0_col9 {
#             background-color:  #dbdcde;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row0_col10 {
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row0_col11 {
#             background-color:  #d75445;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row0_col12 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row0_col13 {
#             background-color:  #d4dbe6;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row0_col14 {
#             background-color:  #f39577;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row0_col15 {
#             background-color:  #bd1f2d;
#             color:  #f1f1f1;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row0_col16 {
#             background-color:  #e6d7cf;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row0_col17 {
#             background-color:  #ccd9ed;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row0_col18 {
#             background-color:  #ead4c8;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row0_col19 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row0_col20 {
#             background-color:  #dc5d4a;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row0_col21 {
#             background-color:  #ee8669;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row0_col22 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row0_col23 {
#             background-color:  #f7a98b;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row0_col24 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row0_col25 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row0_col26 {
#             background-color:  #f08a6c;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row0_col27 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row0_col28 {
#             background-color:  #efcfbf;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row0_col29 {
#             background-color:  #aec9fc;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row1_col0 {
#             background-color:  #c0d4f5;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row1_col1 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row1_col2 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row1_col3 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row1_col4 {
#             background-color:  #ead5c9;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row1_col5 {
#             background-color:  #a9c6fd;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row1_col6 {
#             background-color:  #d2dbe8;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row1_col7 {
#             background-color:  #dedcdb;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row1_col8 {
#             background-color:  #f39475;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row1_col9 {
#             background-color:  #e46e56;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row1_col10 {
#             background-color:  #ea7b60;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row1_col11 {
#             background-color:  #c0282f;
#             color:  #f1f1f1;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row1_col12 {
#             background-color:  #e2dad5;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row1_col13 {
#             background-color:  #e4d9d2;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row1_col14 {
#             background-color:  #da5a49;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row1_col15 {
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row1_col16 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row1_col17 {
#             background-color:  #dd5f4b;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row1_col18 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row1_col19 {
#             background-color:  #f59c7d;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row1_col20 {
#             background-color:  #cfdaea;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row1_col21 {
#             background-color:  #e16751;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row1_col22 {
#             background-color:  #f7b79b;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row1_col23 {
#             background-color:  #f59c7d;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row1_col24 {
#             background-color:  #e67259;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row1_col25 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row1_col26 {
#             background-color:  #afcafc;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row1_col27 {
#             background-color:  #9dbdff;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row1_col28 {
#             background-color:  #b7cff9;
#             color:  #000000;
#         }    #T_9f8fe60e_2605_11eb_a36d_a45e60ddd605row1_col29 {
#             background-color:  #

# %%
df2.groupby(['stateresponse1'])['id'].count().sort_values(ascending = False).plot.bar()

# %% [markdown]
# # Europe DataFrame
# * creating a dataframe with only Europe data

# %%
edf = df2[df2['region'] == 'Europe'].copy()

# %%
edf.shape
# Out:
# (4811, 35)

# %%
plt.figure(figsize=(15,8))
edf.groupby(['year'])['id'].count().sort_index().plot.bar()

# %%
edf.groupby(['year'])['country'].value_counts(normalize = False).sort_index()
# Out:
# year  country
# 1990  Albania                   5
#       Armenia                   1
#       Austria                   1
#       Bulgaria                 35
#       Cyprus                    1
#       Czechoslovakia            4
#       France                   27
#       Georgia                   2
#       Germany                   5
#       Germany East             11
#       Germany West              2
#       Greece                    7
#       Hungary                   5
#       Italy                     1
#       Lithuania                 1
#       Netherlands               1
#       Poland                    4
#       Romania                  63
#       Spain                     4
#       Switzerland               1
#       USSR                     45
#       United Kingdom           36
#       Yugoslavia               25
# 1991  Albania                   8
#       Armenia                   1
#       Azerbaijan                3
#       Bulgaria                  5
#       France                   24
#       Georgia                   5
#       Germany                  15
#       Greece                    5
#       Italy                     2
#       Moldova                   7
#       Poland                    2
#       Portugal                  1
#       Romania                  14
#       Spain                     3
#       Switzerland               1
#       USSR                     15
#       United Kingdom           11
#       Yugoslavia               10
#       Croatia                   1
#       Czech Republic            2
#       France                   19
#       Georgia                   1
#       Germany                  46
#       Greece                    7
#       Hungary                   4
#       Ireland                   6
#       Italy                     8
#       Kosovo                    1
#       Latvia                    2
#       Macedonia                 4
#       Moldova                   4
#       Montenegro                1
#       Netherlands               2
#       Poland                    6
#       Romania                  33
#       Russia                   14
#       Serbia                    3
#       Slovak Republic           1
#       Spain                    24
#       Sweden                    2
#       Ukraine                   3
#       United Kingdom           21
# 2018  Albania                  11
#       Armenia                  18
#       Azerbaijan                2
#       Belarus                   2
#       Belgium                   5
#       Bosnia                   11
#       Bulgaria                  4
#       Croatia                   6
#       Cyprus                    5
#       Czech Republic            6
#       Denmark                   1
#       Estonia                   1
#       Finland                   1
#       France                   42
#       Georgia                   2
#       Germany                  23
#       Greece                    4
#       Hungary                   8
#       Ireland                   9
#       Italy                     9
#       Kosovo                    3
#       Latvia                    4
#       Lithuania                 2
#       Macedonia                 6
#       Moldova                   1
#       Montenegro                1
#       Netherlands               1
#       Poland                    7
#       Portugal                  4
#       Romania                  18
#       Russia                   11
#       Serbia                    4
#       Slovak Republic          13
#       Slovenia                  1
#       Spain                    15
#       Sweden                    2
#       United Kingdom           24
# 2019  Albania                   7
#       Armenia                   1
#       Belgium                   5
#       Croatia                   1
#       France                   13
#       Germany                   2
#       Greece                    2
#       Hungary                   2
#       Ireland                   3
#       Italy                     3
#       Montenegro                1
#       Portugal                  1
#       Russia                    2
#       Serbia                   13
#       Slovak Republic           2
#       Spain                     5
#       Sweden                    3
#       Switzerland               1
#       United Kingdom            5
# Name: country, dtype: int64

# %%
edf.columns
# Out:
# Index(['id', 'country', 'ccode', 'year', 'region', 'protest', 'protestnumber',
#        'startday', 'startmonth', 'startyear', 'endday', 'endmonth', 'endyear',
#        'protesterviolence', 'location', 'participants_category',
#        'participants', 'protesteridentity', 'protesterdemand1',
#        'protesterdemand2', 'protesterdemand3', 'protesterdemand4',
#        'stateresponse1', 'stateresponse2', 'stateresponse3', 'stateresponse4',
#        'stateresponse5', 'stateresponse6', 'stateresponse7', 'sources',
#        'notes', 'outcome', 'startdate', 'enddate', 'datedelta'],
#       dtype='object')

# %% [markdown]
# ### Average duration of protests by year

# %%
plt.figure(figsize=(10,8))
edf.groupby(['year'])['datedelta'].mean().sort_index().head(30).plot.bar()
plt.xticks(rotation=90);

# %% [markdown]
# ### Count of protest demands

# %%
plt.figure(figsize=(15,8))
edf.groupby(['protesterdemand1'])['id'].count().sort_values().plot.bar()

# %% [markdown]
# ### Protests by country

# %%
plt.figure(figsize=(15,8))
edf.groupby(['country'])['id'].count().sort_values().head(50).plot.bar()
plt.xticks(rotation=90);

# %% [markdown]
# ### Avg duration by country

# %%
plt.figure(figsize=(15,8))
edf.groupby(['country'])['datedelta'].mean().sort_values().tail(20).plot.bar()
plt.xticks(rotation=90);

# %% [markdown]
# ### Avg. duration of protests based on stateresponse

# %%
plt.figure(figsize=(10,8))
edf.groupby(['stateresponse1'])['datedelta'].mean().sort_values().head(30).plot.bar()
plt.xticks(rotation=90);

# %%
### Protest duration by european country

# %% [markdown]
# ### Count of protest and response per row

# %%
edf['protestdemands'] = edf[['protesterdemand1','protesterdemand2','protesterdemand3','protesterdemand4']].count(axis = 1)
edf['stateresponses'] = edf[['stateresponse1','stateresponse2','stateresponse3','stateresponse4','stateresponse5','stateresponse6','stateresponse7']].count(axis = 1)

# %% [markdown]
# ### Create bins of participants
# * creating bins (not used in eda)

# %%
#     edf['participants_category'].unique()

#     def protestbins(i):
#         if i < 50: return '>50'
#         elif i <100: return '50-99'
#         elif i <1000: return '100-999'
#         elif i <2000: return '1000-1999'
#         elif i <5000: return '2000-4999'
#         elif i <10001: return'5000-10000'
#         else: return '>10000'


#     protestbins(200000)

#     #edf['participants'].map(protestbins);

# %% [markdown]
# ---

# %%
edf2 = edf.copy()

# %% [markdown]
# ### Create categorical column for response & demand
# * mapping protest demands 1 - 7
# * mapping state response 1 - 7

# %%
stateresponse_codes = {'accomodation':1,'ignore':2,'arrests':3,'crowd dispersal':4,
                       'shootings':5,'beatings':6,'killings':7}
protesterdemand_codes = {'political behavior, process':1,
                         'labor wage dispute':2,
                         'price increases, tax policy':3,
                         'removal of politician':4,
                         'police brutality':5,'land farm issue':6,
                         'social restrictions':7}
#for col in edf2.columns:
#    if 'demand' in col:
#        edf2[col] = edf2[col].map(protesterdemand_codes)
#for col in edf.columns:
#    if 'response' in col:
#        edf2[col] = edf2[col].map(stateresponse_codes)

# %%
edf2['protesterdemand1.1']  = edf2['protesterdemand1'].map(protesterdemand_codes)
edf2['protesterdemand2.1']  = edf2['protesterdemand2'].map(protesterdemand_codes)
edf2['protesterdemand3.1']  = edf2['protesterdemand3'].map(protesterdemand_codes)
edf2['protesterdemand4.1']  = edf2['protesterdemand4'].map(protesterdemand_codes)

# %%
edf2['stateresponse1.1']  = edf2['stateresponse1'].map(stateresponse_codes)
edf2['stateresponse2.1']  = edf2['stateresponse2'].map(stateresponse_codes)
edf2['stateresponse3.1']  = edf2['stateresponse3'].map(stateresponse_codes)
edf2['stateresponse4.1']  = edf2['stateresponse4'].map(stateresponse_codes)
edf2['stateresponse5.1']  = edf2['stateresponse5'].map(stateresponse_codes)
edf2['stateresponse6.1']  = edf2['stateresponse6'].map(stateresponse_codes)
edf2['stateresponse7.1']  = edf2['stateresponse7'].map(stateresponse_codes)

# %%
edf3 = edf2.fillna(999);

# %% [markdown]
# ### Baseline for initial stateresponse

# %%
# for all responses

edf3['stateresponse1'].value_counts(normalize = True)
# Out:
# ignore             0.674496
# crowd dispersal    0.207233
# arrests            0.053004
# accomodation       0.048639
# beatings           0.010393
# shootings          0.004365
# killings           0.001247
# 999                0.000624
# Name: stateresponse1, dtype: float64

# %%
# for accomodations vs all 

edf3['outcome'].value_counts(normalize = True)
# Out:
# 0    0.951361
# 1    0.048639
# Name: outcome, dtype: float64

# %%
edf3['outcome'].value_counts()
# Out:
# 0    4577
# 1     234
# Name: outcome, dtype: int64

# %% [markdown]
# ### Creating features and a list of variables to drop

# %%
# columns to drop for X variables 

drop = ['id', 'startday', 'endday', 'participants_category', 'participants', 'protesteridentity', 'sources', 'notes','outcome', 
       'location', 'protesterdemand1',
       'protesterdemand2', 'protesterdemand3', 'protesterdemand4',
       'stateresponse1', 'stateresponse2', 'stateresponse3', 'stateresponse4',
       'stateresponse5', 'stateresponse6', 'stateresponse7','startdate', 'enddate']

# %%
# X features 

features = edf3.drop(columns = drop)

# %%
features;

# %% [markdown]
# ### Dummy columns

# %%
features.columns
# Out:
# Index(['country', 'ccode', 'year', 'region', 'protest', 'protestnumber',
#        'startmonth', 'startyear', 'endmonth', 'endyear', 'protesterviolence',
#        'datedelta', 'protestdemands', 'stateresponses', 'protesterdemand1.1',
#        'protesterdemand2.1', 'protesterdemand3.1', 'protesterdemand4.1',
#        'stateresponse1.1', 'stateresponse2.1', 'stateresponse3.1',
#        'stateresponse4.1', 'stateresponse5.1', 'stateresponse6.1',
#        'stateresponse7.1'],
#       dtype='object')

# %%
dummy = ['country', 'ccode', 'year', 'region', 'startmonth','startyear','endmonth','endyear']

# remove ccode to align with group

# %%
features2 = pd.get_dummies(features, columns = dummy, drop_first = True);

# %% [markdown]
# ### Variables - Binary

# %%
y = edf3['outcome']
X = features2

# %% [markdown]
# ---

# %% [markdown]
# # Modeling

# %%
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV

from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

from sklearn.ensemble import AdaBoostClassifier, BaggingClassifier, RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import confusion_matrix, plot_confusion_matrix, accuracy_score, recall_score, precision_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 100, stratify = y)

# %% [markdown]
# ### Model Pipeline - Binary

# %%
plr = Pipeline ([('ss', StandardScaler()),
         ('lr', LogisticRegression(max_iter = 5000))])

pknn = Pipeline ([('ss', StandardScaler()),
                     ('knn', KNeighborsClassifier())])

prf = Pipeline ([('ss', StandardScaler()),
                     ('rf', RandomForestClassifier())])

pdt = Pipeline ([('ss', StandardScaler()),
                     ('dt', DecisionTreeClassifier())])

pbg = Pipeline ([('ss', StandardScaler()),
                     ('bg', BaggingClassifier())])

pab = Pipeline ([('ss', StandardScaler()),
                     ('gb', AdaBoostClassifier())])

psv = Pipeline ([('ss', StandardScaler()),
                     ('svc', SVC())])

# %%
classification_models = [plr, pknn, prf, pdt, pbg, pab, psv]

# %%
for model in classification_models:
    model.fit(X_train, y_train)

# %% [markdown]
# ### Model Pipeline Scoring

# %%
# logistic regression

plr.score(X_train, y_train), plr.score(X_test, y_test)
# Out:
# (0.9528824833702882, 0.9517871986699917)

# %%
# Knn

pknn.score(X_train, y_train), pknn.score(X_test, y_test)
# Out:
# (0.9539911308203991, 0.9484621778886118)

# %%
# adaboost

pab.score(X_train, y_train), pab.score(X_test, y_test)
# Out:
# (1.0, 1.0)

# %%
# SVC 

psv.score(X_train, y_train), psv.score(X_test, y_test)
# Out:
# (0.9517738359201774, 0.9509559434746467)

# %%
# Binary confusion matrix

# %%
preds_plr = plr.predict(X_test)

# %%
tn, fp, fn, tp = confusion_matrix(y_test, preds_plr).ravel()
print(f'Specificity: {tn / (fp + tn)}')
print(f'Sensitivity: {tp / (fn + tp)}')
print(f'Precision:   {tp / (tp + fp)}')
print(f'Accuracy:   {plr.score(X_test, y_test)}')
# Out:
# Specificity: 1.0
# Sensitivity: 0.01694915254237288
# Precision:   1.0
# Accuracy:   0.9517871986699917

# %%
plot_confusion_matrix(plr, X_test, y_test,display_labels = ['no accommodation', 'accomodation'],cmap='Blues', values_format='d');

# %%
display_labels = ['no accommodation', 'accomodation']

# %% [markdown]
# ### MultiClass Modeling

# %%
X.head(4)
# Out:
#       protest  protestnumber  protesterviolence  datedelta  protestdemands  \
# 2697        1              1                0.0          0               1
# 2698        1              2                0.0          0               2
# 2699        1              3                0.0          0               2
# 2700        1              4                0.0          0               2
#
#       stateresponses  protesterdemand1.1  protesterdemand2.1  \
# 2697               1                   2               999.0
# 2698               1                   3                 1.0
# 2699               2                   1                 3.0
# 2700               1                   3                 1.0
#
#       protesterdemand3.1  protesterdemand4.1  stateresponse1.1  \
# 2697               999.0               999.0               2.0
# 2698               999.0               999.0               2.0
# 2699               999.0               999.0               4.0
# 2700               999.0               999.0               4.0
#
#       stateresponse2.1  stateresponse3.1  stateresponse4.1  stateresponse5.1  \
# 2697             999.0             999.0             999.0             999.0
# 2698             999.0             999.0             999.0             999.0
# 2699               3.0             999.0             999.0             999.0
# 2700             999.0             999.0             999.0             999.0
#
#       stateresponse6.1  stateresponse7.1  country_Armenia  country_Austria  \
# 2697             999.0             999.0                0                0
# 2698             999.0             999.0                0                0
# 2699             999.0             999.0                0                0
# 2700             999.0             999.0                0                0
#
#       country_Azerbaijan  country_Belarus  country_Belgium  country_Bosnia  \
# 2697                   0                0                0               0
# 2698                   0                0                0               0
# 2699                   0                0                0               0
# 2700                   0                0                0               0
#
#       country_Bulgaria  country_Croatia  country_Cyprus  \
# 2697                 0                0               0
# 2698                 0                0               0
# 2699                 0                0               0
# 2700                 0                0               0
#
#       country_Czech Republic  country_Czechoslovakia  country_Denmark  \
# 2697                       0                       0                0
# 2698                       0                       0                0
# 2699                       0                       0                0
# 2700                       0                       0                0
#
#       country_Estonia  country_Finland  country_France  country_Georgia  \
# 2697                0                0               0                0
# 2698                0                0               0                0
# 2699                0                0               0                0
# 2700                0                0               0                0
#
#       country_Germany  country_Germany East  country_Germany West  \
# 2697                0                     0                     0
# 2698                0                     0                     0
# 2699                0                     0                     0
# 2700                0                     0                     0
#
#       country_Greece  country_Hungary  country_Ireland  country_Italy  \
# 2697               0                0                0              0
# 2698               0                0                0              0
# 2699               0                0                0              0
# 2700               0                0                0              0
#
#       country_Kosovo  country_Latvia  country_Lithuania  country_Luxembourg  \
# 2697               0               0                  0                   0
# 2698               0               0                  0                   0
# 2699               0               0                  0                   0
# 2700               0               0                  0                   0
#
#       country_Macedonia  country_Moldova  country_Montenegro  \
# 2697                  0                0                   0
# 2698                  0                0                   0
# 2699                  0                0                   0
# 2700                  0                0                   0
#
#       country_Netherlands  country_Norway  country_Poland  country_Portugal  \
# 2697                    0               0               0                 0
# 2698                    0               0               0                 0
# 2699                    0               0               0                 0
# 2700                    0               0               0                 0
#
#       country_Romania  country_Russia  country_Serbia  \
# 2697                0               0               0
# 2698                0               0               0
# 2699                0               0               0
# 2700                0               0               0
#
#       country_Serbia and Montenegro  country_Slovak Republic  \
# 2697                              0                        0
# 2698                              0                        0
# 2699                              0                        0
# 2700                              0                        0
#
#       country_Slovenia  country_Spain  country_Sweden  country_Switzerland  \
# 2697                 0              0               0                    0
# 2698                 0              0               0                    0
# 2699                 0              0               0                    0
# 2700                 0              0               0                    0
#
#       country_USSR  country_Ukraine  country_United Kingdom  \
# 2697             0                0                       1
# 2698             0                0                       1
# 2699             0                0                       1
# 2700             0                0                       1
#
#       country_Yugoslavia  ccode_205  ccode_210  ccode_211  ccode_212  \
# 2697                   0          0          0          0          0
# 2698                   0          0          0          0          0
# 2699                   0          0          0          0          0
# 2700                   0          0          0          0          0
#
#       ccode_220  ccode_225  ccode_230  ccode_235  ccode_255  ccode_260  \
# 2697          0          0          0          0          0          0
# 2698          0          0          0          0          0          0
# 2699          0          0          0          0          0          0
# 2700          0          0          0          0          0          0
#
#       ccode_265  ccode_290  ccode_305  ccode_310  ccode_315  ccode_316  \
# 2697          0          0          0          0          0          0
# 2698          0          0          0          0          0          0
# 2699          0          0          0          0          0          0
# 2700          0          0          0          0          0          0
#
#       ccode_317  ccode_325  ccode_339  ccode_341  ccode_342  ccode_343  \
# 2697          0          0          0          0          0          0
# 2698          0          0          0          0          0          0
# 2699          0          0          0          0          0          0
# 2700          0          0          0          0          0          0
#
#       ccode_344  ccode_345  ccode_346  ccode_347  ccode_348  ccode_349  \
# 2697          0          0          0          0          0          0
# 2698          0          0          0          0          0          0
# 2699          0          0          0          0          0          0
# 2700          0          0          0          0          0          0
#
#       ccode_350  ccode_352  ccode_355  ccode_359  ccode_360  ccode_364  \
# 2697          0          0          0          0          0          0
# 2698          0          0          0          0          0          0
# 2699          0          0          0          0          0          0
# 2700          0          0          0          0          0          0
#
#       ccode_365  ccode_366  ccode_367  ccode_368  ccode_369  ccode_370  \
# 2697          0          0          0          0          0          0
# 2698          0          0          0          0          0          0
# 2699          0          0          0          0          0          0
# 2700          0          0          0          0          0          0
#
#       ccode_371  ccode_372  ccode_373  ccode_375  ccode_380  ccode_385  \
# 2697          0          0          0          0          0          0
# 2698          0          0          0          0          0          0
# 2699          0          0          0          0          0          0
# 2700          0          0          0          0          0          0
#
#       ccode_390  year_1991  year_1992  year_1993  year_1994  year_1995  \
# 2697          0          0          0          0          0          0
# 2698          0          0          0          0          0          0
# 2699          0          0          0          0          0          0
# 2700          0          0          0          0          0          0
#
#       year_1996  year_1997  year_1998  year_1999  year_2000  year_2001  \
# 2697          0          0          0          0          0          0
# 2698          0          0          0          0          0          0
# 2699          0          0          0          0          0          0
# 2700          0          0          0          0          0          0
#
#       year_2002  year_2003  year_2004  year_2005  year_2006  year_2007  \
# 2697          0          0          0          0          0          0
# 2698          0          0          0          0          0          0
# 2699          0          0          0          0          0          0
# 2700          0          0          0          0          0          0
#
#       year_2008  year_2009  year_2010  year_2011  year_2012  year_2013  \
# 2697          0          0          0          0          0          0
# 2698          0          0          0          0          0          0
# 2699          0          0          0          0          0          0
# 2700          0          0          0          0          0          0
#
#       year_2014  year_2015  year_2016  year_2017  year_2018  year_2019  \
# 2697          0          0          0          0          0          0
# 2698          0          0          0          0          0          0
# 2699          0          0          0          0          0          0
# 2700          0          0          0          0          0          0
#
#       startmonth_2  startmonth_3  startmonth_4  startmonth_5  startmonth_6  \
# 2697             0             0             0             0             0
# 2698             1             0             0             0             0
# 2699             1             0             0             0             0
# 2700             1             0             0             0             0
#
#       startmonth_7  startmonth_8  startmonth_9  startmonth_10  startmonth_11  \
# 2697             0             0             0              0              0
# 2698             0             0             0              0              0
# 2699             0             0             0              0              0
# 2700             0             0             0              0              0
#
#       startmonth_12  startyear_1991  startyear_1992  startyear_1993  \
# 2697              0               0               0               0
# 2698              0               0               0               0
# 2699              0               0               0               0
# 2700              0               0               0               0
#
#       startyear_1994  startyear_1995  startyear_1996  startyear_1997  \
# 2697               0               0               0               0
# 2698               0               0               0               0
# 2699               0               0               0               0
# 2700               0               0               0               0
#
#       startyear_1998  startyear_1999  startyear_2000  startyear_2001  \
# 2697               0               0               0               0
# 2698               0               0               0               0
# 2699               0               0               0               0
# 2700               0               0               0               0
#
#       startyear_2002  startyear_2003  startyear_2004  startyear_2005  \
# 2697               0               0               0               0
# 2698               0               0               0               0
# 2699               0               0               0               0
# 2700               0               0               0               0
#
#       startyear_2006  startyear_2007  startyear_2008  startyear_2009  \
# 2697               0               0               0               0
# 2698               0               0               0               0
# 2699               0               0               0               0
# 2700               0               0               0               0
#
#       startyear_2010  startyear_2011  startyear_2012  startyear_2013  \
# 2697               0               0               0               0
# 2698               0               0               0               0
# 2699               0               0               0               0
# 2700               0               0               0               0
#
#       startyear_2014  startyear_2015  startyear_2016  startyear_2017  \
# 2697               0               0               0               0
# 2698               0               0               0               0
# 2699               0               0               0               0
# 2700               0               0               0               0
#
#       startyear_2018  startyear_2019  endmonth_2  endmonth_3  endmonth_4  \
# 2697               0               0           0           0           0
# 2698               0               0           1           0           0
# 2699               0               0           1           0           0
# 2700               0               0           1           0           0
#
#       endmonth_5  endmonth_6  endmonth_7  endmonth_8  endmonth_9  endmonth_10  \
# 2697           0           0           0           0           0            0
# 2698           0           0           0           0           0            0
# 2699           0           0           0           0           0            0
# 2700           0           0           0           0           0            0
#
#       endmonth_11  endmonth_12  endyear_1991  endyear_1992  endyear_1993  \
# 2697            0            0             0             0             0
# 2698            0            0             0             0             0
# 2699            0            0             0             0             0
# 2700            0            0             0             0             0
#
#       endyear_1994  endyear_1995  endyear_1996  endyear_1997  endyear_1998  \
# 2697             0             0             0             0             0
# 2698             0             0             0             0             0
# 2699             0             0             0             0             0
# 2700             0             0             0             0             0
#
#       endyear_1999  endyear_2000  endyear_2001  endyear_2002  endyear_2003  \
# 2697             0             0             0             0             0
# 2698             0             0             0             0             0
# 2699             0             0             0             0             0
# 2700             0             0             0             0             0
#
#       endyear_2004  endyear_2005  endyear_2006  endyear_2007  endyear_2008  \
# 2697             0             0             0             0             0
# 2698             0             0             0             0             0
# 2699             0             0             0             0             0
# 2700             0             0             0             0             0
#
#       endyear_2009  endyear_2010  endyear_2011  endyear_2012  endyear_2013  \
# 2697             0             0             0             0             0
# 2698             0             0             0             0             0
# 2699             0             0             0             0             0
# 2700             0             0             0             0             0
#
#       endyear_2014  endyear_2015  endyear_2016  endyear_2017  endyear_2018  \
# 2697             0             0             0             0             0
# 2698             0             0             0             0             0
# 2699             0             0             0             0             0
# 2700             0             0             0             0             0
#
#       endyear_2019
# 2697             0
# 2698             0
# 2699             0
# 2700             0

# %% [markdown]
# ### Multi Class Variables

# %%
y2 = edf3['stateresponse1.1']

# %%
drop2 = ['id', 'startday', 'endday', 'participants_category', 'participants', 'protesteridentity', 'sources', 'notes', 
       'location', 'protesterdemand1',
       'protesterdemand2', 'protesterdemand3', 'protesterdemand4',
       'stateresponse1', 'stateresponse2', 'stateresponse3', 'stateresponse4',
       'stateresponse5', 'stateresponse6', 'stateresponse7','startdate', 'enddate','stateresponse1.1']

# %%
dummy2 = ['country', 'ccode', 'year', 'region', 'startmonth','startyear','endmonth','endyear']

# %%
featuresMC = edf3.drop(columns = drop2)

# %%
featuresMC = pd.get_dummies(featuresMC, columns = dummy2, drop_first = True);

# %%
X2 = featuresMC

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X2, y2, random_state = 100, stratify = y)

# %% [markdown]
# ### Modeling - fitting models for multiclass

# %%
for model in classification_models:
    model.fit(X_train2, y_train2)

# %%
# Logistic Regression
plr.score(X_train2, y_train2), plr.score(X_test2, y_test2)
# Out:
# (0.8378603104212861, 0.830423940149626)

# %%
# knn
pknn.score(X_train2, y_train2), pknn.score(X_test2, y_test2)
# Out:
# (0.7649667405764967, 0.7090606816292602)

# %%
# sv 

psv.score(X_train2, y_train2), psv.score(X_test2, y_test2)
# Out:
# (0.8472838137472284, 0.8345802161263508)

# %%
# adaboost

pab.score(X_train2, y_train2), pab.score(X_test2, y_test2)
# Out:
# (0.8170731707317073, 0.8312551953449709)

# %%
# multiclass confusion matrix

# %%
pred = pab.predict(X_test2)

# %%
plot_confusion_matrix(pab, X_test2, y_test2, cmap='Blues', values_format='d');
